# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup

import hvplot.pandas
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import cartopy
import geoviews
import json

# Import API key
from api_keys import geoapify_key
import warnings
warnings.filterwarnings("ignore")
geoapify_key = '56a49f877f2b491584feb19ecd83de6a'
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# //anaconda3/envs/myenv/lib/python3.8/site-packages/geoviews/operation/__init__.py:14: HoloviewsDeprecationWarning: 'ResamplingOperation' is deprecated and will be removed in version 1.18, use 'ResampleOperation2D' instead.
#   from holoviews.operation.datashader import (

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0    qarqaraly  49.4058   75.4742    278.92        56           3
# 1        1   hood river  45.7054 -121.5215    299.36        48           0
# 2        2    adamstown -25.0660 -130.1015    295.93        78          57
# 3        3  kailua-kona  19.6406 -155.9956    302.13        79          40
# 4        4       albany  42.6001  -73.9662    285.50        83          96
#
#    Wind Speed Country        Date
# 0        3.32      KZ  1697670827
# 1        0.89      US  1697670827
# 2        3.34      PN  1697670828
# 3        5.14      US  1697670538
# 4        0.97      US  1697670598

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    x='Lng',
    y='Lat',
    size ='Humidity',
    geo=True,
    tiles="OSM",
    frame_width=800,
    frame_height=600,
    color = "City"
)
# Display the map plot
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_df = city_data_df[ (city_data_df["Max Temp"] >= 22) &  (city_data_df["Humidity"] <= 60) ]
clean_ideal_city_df = ideal_df[ ideal_df["Cloudiness"] == 0 ] 

# Drop any rows with null values
clean_ideal_data_df = clean_ideal_city_df.dropna()

# Display sample data
clean_ideal_data_df
# Out:
#      City_ID                   City      Lat       Lng  Max Temp  Humidity  \
# 1          1             hood river  45.7054 -121.5215    299.36        48
# 56        56                 newman  37.3138 -121.0208    305.50        34
# 62        62             mandalgovi  45.7625  106.2708    273.37        47
# 77        77               tshabong -26.0500   22.4500    293.68        28
# 91        91                 kodiak  57.7900 -152.4072    283.88        35
# 100      100              kununurra -15.7667  128.7333    296.14        49
# 101      101                klyuchi  52.2667   79.1667    280.17        50
# 108      108                pahrump  36.2083 -115.9839    307.73        11
# 145      145                   page  36.9147 -111.4558    302.03        15
# 154      154                 urzhar  47.0930   81.6294    283.10        38
# 160      160                  aswan  24.0934   32.9070    295.76        33
# 187      187                 neyriz  29.1988   54.3278    289.23        32
# 191      191                 gering  41.8258 -103.6605    291.55        23
# 221      221               karratha -20.7377  116.8463    301.42        34
# 235      235                  altai  46.3722   96.2583    272.61        59
# 244      244             huntsville  34.7304  -86.5861    293.32        52
# 255      255                 rawson -43.3002  -65.1023    300.31        12
# 270      270               hashtrud  37.4779   47.0508    284.39        59
# 288      288           punta arenas -53.1500  -70.9167    286.21        54
# 315      315           north platte  41.1239 -100.7654    292.66        36
# 316      316                shihezi  44.3000   86.0333    281.62        35
# 322      322            broken hill -31.9500  141.4333    296.69        23
# 328      328            as sulayyil  20.4607   45.5779    296.29        23
# 364      364             miles city  46.4083 -105.8406    290.69        34
# 378      378                 snyder  32.7179 -100.9176    302.21        21
# 418      418          lacy-lakeview  31.6293  -97.1028    300.33        34
# 422      422                  darab  28.7519   54.5444    292.99        30
# 426      426                 gaiman -43.2897  -65.4929    300.26        14
# 438      438               fiambala -27.6871  -67.6149    295.08        28
# 448      448              los lunas  34.8062 -106.7334    303.07        15
# 452      452                 medina  24.4686   39.6142    301.39        18
# 483      483           port hedland -20.3167  118.5667    302.18        15
# 505      505                 zaysan  47.4667   84.8667    281.50        30
# 364             miles city      US  46.4083 -105.8406        34
# 378                 snyder      US  32.7179 -100.9176        21
# 418          lacy-lakeview      US  31.6293  -97.1028        34
# 422                  darab      IR  28.7519   54.5444        30
# 426                 gaiman      AR -43.2897  -65.4929        14
# 438               fiambala      AR -27.6871  -67.6149        28
# 448              los lunas      US  34.8062 -106.7334        15
# 452                 medina      SA  24.4686   39.6142        18
# 483           port hedland      AU -20.3167  118.5667        15
# 505                 zaysan      KZ  47.4667   84.8667        30
# 516               ajdabiya      LY  30.7554   20.2263        34
# 518           rio gallegos      AR -51.6226  -69.2181        39
# 528                   naze      JP  28.3667  129.4833        57
# 535                  seydi      TM  39.4816   62.9137        48
# 543           nishinoomote      JP  30.7333  131.0000        59
# 547             laojunmiao      CN  39.8333   97.7333        30
# 549  truth or consequences      US  33.1284 -107.2528        13

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel

radius = 10000
categories = 'accommodation.hotel'
limit = 1
params = {
    "categories":categories,
    "limit":limit,
    "apiKey":geoapify_key    
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    city_lat = row.loc['Lat']
    city_lng = row.loc['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    filter = f"circle:{city_lng},{city_lat},{radius}"
    bias = f"proximity:{city_lng},{city_lat}"
    params["filter"] = filter
    params["bias"] = bias
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params).json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# hood river - nearest hotel: Hood River Hotel
# newman - nearest hotel: No hotel found
# mandalgovi - nearest hotel: АЛТАНГОВЬ Hotel
# tshabong - nearest hotel: No hotel found
# kodiak - nearest hotel: Shelikof Lodge
# kununurra - nearest hotel: Kununurra Country Club Resort
# klyuchi - nearest hotel: No hotel found
# pahrump - nearest hotel: Holiday Inn Express & Suites
# page - nearest hotel: Clarion Inn Page - Lake Powell
# urzhar - nearest hotel: Sharikan
# aswan - nearest hotel: Yaseen hotel
# neyriz - nearest hotel: No hotel found
# gering - nearest hotel: Arcadia Hotel
# karratha - nearest hotel: Karratha International Hotel
# altai - nearest hotel: Altai hotel 40000-100000T
# huntsville - nearest hotel: 106 Jefferson Huntsville, Curio Collection by Hilton
# rawson - nearest hotel: Hotel Deportivo
# hashtrud - nearest hotel: No hotel found
# punta arenas - nearest hotel: Hotel Lacolet
# north platte - nearest hotel: Howard Johnson Inn - North Platte
# shihezi - nearest hotel: 石河子宾馆
# broken hill - nearest hotel: Ibis Styles
# as sulayyil - nearest hotel: No hotel found
# miles city - nearest hotel: Historic Olive Hotel
# snyder - nearest hotel: Days Inn
# lacy-lakeview - nearest hotel: Classic Inn
# darab - nearest hotel: محدوده هتل جهانگردی
# gaiman - nearest hotel: yr hen ffordd
# fiambala - nearest hotel: Cabañas Lunita
# los lunas - nearest hotel: Los Lunas Inn & Suites
# medina - nearest hotel: The Oberoi Madina
# port hedland - nearest hotel: The Esplanade Hotel
# zaysan - nearest hotel: Рахат қонақүй
# ajdabiya - nearest hotel: فندق المدينة
# rio gallegos - nearest hotel: Amérian Río Gallegos Apart & Suites
# naze - nearest hotel: ビジネス旅館畠山
# seydi - nearest hotel: No hotel found
# nishinoomote - nearest hotel: ゼウスハウス
# laojunmiao - nearest hotel: No hotel found
# truth or consequences - nearest hotel: Travelodge
#                       City Country      Lat       Lng  Humidity  \
# 1               hood river      US  45.7054 -121.5215        48
# 56                  newman      US  37.3138 -121.0208        34
# 62              mandalgovi      MN  45.7625  106.2708        47
# 77                tshabong      BW -26.0500   22.4500        28
# 91                  kodiak      US  57.7900 -152.4072        35
# 100              kununurra      AU -15.7667  128.7333        49
# 101                klyuchi      RU  52.2667   79.1667        50
# 108                pahrump      US  36.2083 -115.9839        11
# 145                   page      US  36.9147 -111.4558        15
# 154                 urzhar      KZ  47.0930   81.6294        38
# 160                  aswan      EG  24.0934   32.9070        33
# 187                 neyriz      IR  29.1988   54.3278        32
# 191                 gering      US  41.8258 -103.6605        23
# 221               karratha      AU -20.7377  116.8463        34
# 235                  altai      MN  46.3722   96.2583        59
# 244             huntsville      US  34.7304  -86.5861        52
# 255                 rawson      AR -43.3002  -65.1023        12
# 270               hashtrud      IR  37.4779   47.0508        59
# 288           punta arenas      CL -53.1500  -70.9167        54
# 315           north platte      US  41.1239 -100.7654        36
# 316                shihezi      CN  44.3000   86.0333        35
# 322            broken hill      AU -31.9500  141.4333        23
# 328            as sulayyil      SA  20.4607   45.5779        23
# 364             miles city      US  46.4083 -105.8406        34
# 378                 snyder      US  32.7179 -100.9176        21
# 418          lacy-lakeview      US  31.6293  -97.1028        34
# 422                  darab      IR  28.7519   54.5444        30
# 426                 gaiman      AR -43.2897  -65.4929        14
# 438               fiambala      AR -27.6871  -67.6149        28
# 448              los lunas      US  34.8062 -106.7334        15
# 452                 medina      SA  24.4686   39.6142        18
# 483           port hedland      AU -20.3167  118.5667        15
# 505                 zaysan      KZ  47.4667   84.8667        30
# 516               ajdabiya      LY  30.7554   20.2263        34
# 518           rio gallegos      AR -51.6226  -69.2181        39
# 528                   naze      JP  28.3667  129.4833        57
# 535                  seydi      TM  39.4816   62.9137        48
# 543           nishinoomote      JP  30.7333  131.0000        59
# 547             laojunmiao      CN  39.8333   97.7333        30
# 549  truth or consequences      US  33.1284 -107.2528        13
#
#                                             Hotel Name
# 1                                     Hood River Hotel
# 56                                      No hotel found
# 62                                     АЛТАНГОВЬ Hotel
# 77                                      No hotel found
# 91                                      Shelikof Lodge
# 100                      Kununurra Country Club Resort
# 101                                     No hotel found
# 108                       Holiday Inn Express & Suites
# 145                     Clarion Inn Page - Lake Powell
# 154                                           Sharikan
# 160                                       Yaseen hotel
# 187                                     No hotel found
# 191                                      Arcadia Hotel
# 221                       Karratha International Hotel
# 235                          Altai hotel 40000-100000T
# 244  106 Jefferson Huntsville, Curio Collection by ...
# 255                                    Hotel Deportivo
# 270                                     No hotel found
# 288                                      Hotel Lacolet
# 315                  Howard Johnson Inn - North Platte
# 316                                              石河子宾馆
# 322                                        Ibis Styles
# 328                                     No hotel found
# 364                               Historic Olive Hotel
# 378                                           Days Inn
# 418                                        Classic Inn
# 422                                محدوده هتل جهانگردی
# 426                                      yr hen ffordd
# 438                                     Cabañas Lunita
# 448                             Los Lunas Inn & Suites
# 452                                  The Oberoi Madina
# 483                                The Esplanade Hotel
# 505                                      Рахат қонақүй
# 516                                       فندق المدينة
# 518                Amérian Río Gallegos Apart & Suites
# 528                                           ビジネス旅館畠山
# 535                                     No hotel found
# 543                                             ゼウスハウス
# 547                                     No hotel found
# 549                                         Travelodge

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    color = "City",
    hover_cols = ['City','Humidity','Hotel Name','Country']
)
hvplot.save(map_plot_2, '../output_data/Hotels.html')

# Display the map
map_plot_2
# Out:
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Row(id='1726', ...)
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
